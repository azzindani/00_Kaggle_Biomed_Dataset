# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_Kaggle_Dataset/blob/main/Cardiac_Segmentation_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 00 Import Modules

# %%
#!pip install -q pydicom
# !command -v ffmpeg >/dev/null || (apt update && apt install -y ffmpeg)
# !pip install -q mediapy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.9 MB/s eta 0:00:00

# %%
import os
import json
import nibabel as nib
import matplotlib.pyplot as plt
#import pydicom
import numpy as np
import cv2
import subprocess
import itertools
import mediapy as media

from PIL import Image
from IPython.display import Audio, Video, HTML
from matplotlib.animation import FuncAnimation
from base64 import b64encode
from io import BytesIO
from zipfile import ZipFile

# %% [markdown]
# ## 01 Download Dataset

# %%
url = 'https://www.kaggle.com/datasets/samdazel/automated-cardiac-diagnosis-challenge-miccai17'

url_path = url.split('datasets/')[1]
url_path
# Out:
# 'samdazel/automated-cardiac-diagnosis-challenge-miccai17'

# %%
# !kaggle datasets download -d {url_path}
# Out:
# Dataset URL: https://www.kaggle.com/datasets/samdazel/automated-cardiac-diagnosis-challenge-miccai17
# License(s): apache-2.0
# Downloading automated-cardiac-diagnosis-challenge-miccai17.zip to /content
# 100% 2.10G/2.11G [00:27<00:00, 149MB/s]
# 100% 2.11G/2.11G [00:27<00:00, 82.1MB/s]

# %% [markdown]
# ## 02 Extract Dataset

# %%
os.listdir()
# Out:
# ['.config',
#  'automated-cardiac-diagnosis-challenge-miccai17.zip',
#  'sample_data']

# %%
zipfile = ZipFile(os.listdir()[1])
zipfile.extractall() #'''

# %% [markdown]
# ## 03 Get File List

# %%
root_dir = '/content/'
n = 20

counter = 0

path_list = []

for dirpath, dirnames, filenames in os.walk(root_dir):
  for filename in filenames:
    path_list.append(dirpath + '/' + filename)

  counter += 1
  if counter >= n:
    break

#path_list

# %%
file_format = '.nii'
n = 5
file_paths = []

for root, dirs, files in os.walk(root_dir):
  for file in files:
    if file.endswith(file_format):
      file_paths.append(os.path.join(root, file))

    if len(file_paths) >= n:
      break
  if len(file_paths) >= n:
    break

file_paths
# Out:
# ['/content/database/testing/patient129/patient129_frame08.nii',
#  '/content/database/testing/patient129/patient129_frame01_gt.nii',
#  '/content/database/testing/patient129/patient129_frame08_gt.nii',
#  '/content/database/testing/patient129/patient129_frame01.nii',
#  '/content/database/testing/patient129/patient129_4d.nii']

# %% [markdown]
# | Modality | Highlights / Use Cases                                      | Appearance Characteristics                   |
# |----------|-------------------------------------------------------------|-----------------------------------------------|
# | **T1 (T1-weighted imaging)**   | Anatomy, fat, gray/white matter differentiation              | CSF appears dark; gray/white matter is distinct. |
# | **FLAIR (Fluid-Attenuated Inversion Recovery)**| Lesions, abnormalities near CSF (fluid suppression)          | CSF is dark; lesions appear bright.            |
# | **SEG (Segmentation)**  | Tumor regions and sub-regions                                | Binary or labeled mask.                       |
# | **T2 (T2-weighted imaging)**   | Fluid-filled regions like edema, CSF                         | Fluid appears bright.                         |
# | **T1CE (T1 Contrast-Enhanced imaging)** | Active tumor regions (contrast-enhanced)                     | Tumor appears brighter due to contrast agent. |

# %% [markdown]
# | **Modality**   | **Best for Masking**                         | **Highlights**                               | **Use Cases**                                  | **When to Use**                                |
# |----------------|---------------------------------------------|---------------------------------------------|-----------------------------------------------|-----------------------------------------------|
# | **T1CE**       | Active tumor regions                        | Enhancing tumor regions with contrast agent | Tumor characterization and segmentation      | When focusing on **active tumor regions**      |
# | **FLAIR**      | Edema and diffuse tumor regions             | Lesions, edema, and infiltrating tissues    | Identifying edema or diffuse abnormalities    | When segmentation includes **edema** or infiltrative areas |
# | **T2**         | Edema and fluid-related abnormalities       | Fluid-filled regions like edema or cysts    | Analyzing extent of edema or cystic structures | When focusing on **edema** or fluid-related areas |
# | **T1**         | Gross anatomical structures (less common)   | Gray/white matter differentiation           | General anatomy visualization                | When needing **anatomical context**            |

# %% [markdown]
# ## 04 Segmentation Preview

# %% [markdown]
# | **Feature**          | **White Matter**                                             | **Gray Matter**                                               | **Cerebrospinal Fluid (CSF)**                               |
# |-----------------------|------------------------------------------------------------|-------------------------------------------------------------|-----------------------------------------------------------|
# | **Location**          | Inner brain regions (e.g., corpus callosum, deep brain areas). | Outer brain layer (cortex) and subcortical structures (e.g., thalamus). | Ventricles, subarachnoid space, spinal cord canal.        |
# | **Composition**       | Myelinated axons (nerve fibers).                           | Neuronal cell bodies, dendrites, and unmyelinated axons.     | Clear, watery fluid containing nutrients and waste.       |
# | **Function**          | Connects different brain areas for signal transmission.    | Processes information, decision-making, and memory.         | Cushions brain/spinal cord, removes waste, circulates nutrients. |
# | **Appearance in MRI** | Bright on T1, dark on T2.                                   | Intermediate on T1, intermediate/dark on T2.                | Dark on T1, bright on T2.                                 |
# | **Role in Disease**   | Damage linked to demyelination (e.g., multiple sclerosis).  | Affected in neurodegeneration (e.g., Alzheimer's, Parkinson's). | Enlarged spaces indicate atrophy or hydrocephalus.        |
# | **Clinical Imaging**  | Highlighted in T1-weighted MRI for structural integrity.    | Studied in cortical thickness or subcortical volume analysis. | Studied for ventricular size or CSF leaks in MRI/CT.      |

# %%
mask_path = file_paths[1]
mask_path
# Out:
# '/content/database/testing/patient129/patient129_frame01_gt.nii'

# %% [markdown]
# ### 04.01 File Properties Preview

# %%
img = nib.load(mask_path)
img_data = img.get_fdata()

print('Image data shape:', img_data.shape)

header = img.header
print('Header information:', header)
# Out:
# Image data shape: (154, 224, 17)
# Header information: <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b''
# dim_info        : 0
# dim             : [  3 154 224  17   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : uint8
# bitpix          : 8
# slice_start     : 0
# pixdim          : [1.      1.65179 1.65179 5.      1.      1.      1.      1.     ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 0
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 1.0
# qoffset_x       : 0.0
# qoffset_y       : 0.0
# qoffset_z       : 0.0
# srow_x          : [-1. -0.  0.  0.]
# srow_y          : [-0. -1.  0.  0.]
# srow_z          : [0. 0. 1. 0.]
# intent_name     : b''
# magic           : b'n+1'

# %%
plt.imshow(img_data[:, :, img_data.shape[2] // 2], cmap = 'gray')
plt.title('Middle slice')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 04.02 Preview Multiple Images

# %%
img = nib.load(mask_path)
img_data = img.get_fdata()

print('Image data shape:', img_data.shape)

num_slices = 6
slices = np.linspace(0, img_data.shape[2] - 1, num_slices).astype(int)

num_columns = 3
num_rows = (num_slices + num_columns - 1) // num_columns

plt.figure(figsize = (15, 5 * num_rows))

for i, slice_idx in enumerate(slices):
  plt.subplot(num_rows, num_columns, i + 1)
  plt.imshow(img_data[:, :, slice_idx], cmap = 'gray')
  plt.title(f'Slice {slice_idx}')
  plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Image data shape: (154, 224, 17)

# %% [markdown]
# ### 04.03 Preview Selected Image

# %%
slice_idx = 10
plt.imshow(img_data[:, :, slice_idx], cmap = 'gray')
plt.title(f'Slice {slice_idx}')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 04.04 Preview as Video

# %%
img = nib.load(mask_path)
img_data = img.get_fdata()

height, width, n_frames = img_data.shape
print('Image data shape:', img_data.shape)

output_video = 'mask_video.mp4'
fps = 10

fourcc = cv2.VideoWriter_fourcc(*'XVID')
video_writer = cv2.VideoWriter(output_video, fourcc, fps, (width, height), isColor = False)

for i in range(n_frames):
  frame = img_data[:, :, i]
  frame_normalized = cv2.normalize(frame, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
  video_writer.write(frame_normalized)

video_writer.release()
print(f'Video saved as {output_video}')
# Out:
# Image data shape: (154, 224, 17)
# Video saved as mask_video.mp4

# %%
video = media.read_video(output_video)
print(f'Shape is (num_images, height, width, num_channels) = {video.shape}.')
if metadata := video.metadata:
  print(f'Framerate is {metadata.fps} frames/s.')
video2 = media.resize_video(video, tuple(np.array(video.shape[1:3]) // 1))
media.show_video(video2, fps = fps, codec = 'gif')
# Out:
# Shape is (num_images, height, width, num_channels) = (17, 154, 224, 3).
# Framerate is 10.0 frames/s.
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="224" height="154" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>

# %% [markdown]
# ## 05 Original Preview

# %%
ori_path = file_paths[0]
ori_path
# Out:
# '/content/database/testing/patient129/patient129_frame08.nii'

# %% [markdown]
# ### 05.01 File Properties Preview

# %%
img = nib.load(ori_path)
img_data = img.get_fdata()

print('Image data shape:', img_data.shape)

header = img.header
print('Header information:', header)
# Out:
# Image data shape: (154, 224, 17)
# Header information: <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b''
# dim_info        : 0
# dim             : [  3 154 224  17   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.      1.65179 1.65179 5.      1.      1.      1.      1.     ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 0
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 1.0
# qoffset_x       : 0.0
# qoffset_y       : 0.0
# qoffset_z       : 0.0
# srow_x          : [-1. -0.  0.  0.]
# srow_y          : [-0. -1.  0.  0.]
# srow_z          : [0. 0. 1. 0.]
# intent_name     : b''
# magic           : b'n+1'

# %%
plt.imshow(img_data[:, :, img_data.shape[2] // 2], cmap = 'gray')
plt.title('Middle slice')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 05.02 Preview Multiple Images

# %%
img = nib.load(ori_path)
img_data = img.get_fdata()

print('Image data shape:', img_data.shape)

num_slices = 6
slices = np.linspace(0, img_data.shape[2] - 1, num_slices).astype(int)

num_columns = 3
num_rows = (num_slices + num_columns - 1) // num_columns

plt.figure(figsize = (15, 5 * num_rows))

for i, slice_idx in enumerate(slices):
  plt.subplot(num_rows, num_columns, i + 1)
  plt.imshow(img_data[:, :, slice_idx], cmap = 'gray')
  plt.title(f'Slice {slice_idx}')
  plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Image data shape: (154, 224, 17)

# %% [markdown]
# ### 05.03 Preview Selected Image

# %%
slice_idx = 10
plt.imshow(img_data[:, :, slice_idx], cmap = 'gray')
plt.title(f'Slice {slice_idx}')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 05.04 Preview as Video

# %%
img = nib.load(ori_path)
img_data = img.get_fdata()

height, width, n_frames = img_data.shape
print('Image data shape:', img_data.shape)

output_video = 'ori_video.mp4'
fps = 10

fourcc = cv2.VideoWriter_fourcc(*'XVID')
video_writer = cv2.VideoWriter(output_video, fourcc, fps, (width, height), isColor = False)

for i in range(n_frames):
  frame = img_data[:, :, i]
  frame_normalized = cv2.normalize(frame, None, 0, 255, cv2.NORM_MINMAX).astype(np.uint8)
  video_writer.write(frame_normalized)

video_writer.release()
print(f'Video saved as {output_video}')
# Out:
# Image data shape: (154, 224, 17)
# Video saved as ori_video.mp4

# %%
video = media.read_video(output_video)
print(f'Shape is (num_images, height, width, num_channels) = {video.shape}.')
if metadata := video.metadata:
  print(f'Framerate is {metadata.fps} frames/s.')
video2 = media.resize_video(video, tuple(np.array(video.shape[1:3]) // 1))
media.show_video(video2, fps = fps, codec = 'gif')
# Out:
# Shape is (num_images, height, width, num_channels) = (17, 154, 224, 3).
# Framerate is 10.0 frames/s.
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="224" height="154" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>

# %% [markdown]
# ## 06 Masked Preview

# %%
ori_img = nib.load(ori_path)
mask_img = nib.load(mask_path)

ori_data = ori_img.get_fdata()
mask_data = mask_img.get_fdata()

ori_data = (ori_data - np.min(ori_data)) / (np.max(ori_data) - np.min(ori_data))

height, width = ori_data.shape[:2]
fps = 10
output_video_path = 'masked_video.mp4'
ori_opacity = 1
mask_opacity = 0.5

fourcc = cv2.VideoWriter_fourcc(*'XVID')
video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

for i in range(ori_data.shape[2]):
  ori_slice = (ori_data[:, :, i] * 255).astype(np.uint8)
  mask_slice = (mask_data[:, :, i] > 0).astype(np.uint8)

  color_mask = np.zeros((height, width, 3), dtype = np.uint8)
  color_mask[mask_slice == 1] = [255, 0, 0]

  ori_colored = cv2.cvtColor(ori_slice, cv2.COLOR_GRAY2BGR)
  combined_frame = cv2.addWeighted(ori_colored, ori_opacity, color_mask, mask_opacity, 0)
  video_writer.write(combined_frame)

video_writer.release()
print(f"Masked video saved to {output_video_path}")
# Out:
# Masked video saved to masked_video.mp4

# %%
video = media.read_video(output_video_path)
print(f'Shape is (num_images, height, width, num_channels) = {video.shape}.')
if metadata := video.metadata:
  print(f'Framerate is {metadata.fps} frames/s.')
video2 = media.resize_video(video, tuple(np.array(video.shape[1:3]) // 1))
media.show_video(video2, fps = fps, codec = 'gif')
# Out:
# Shape is (num_images, height, width, num_channels) = (17, 154, 224, 3).
# Framerate is 10.0 frames/s.
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="224" height="154" style="image-rendering:auto; object-fit:cover;" src="data:image/gif;base64,..."/></td></tr></table>
